# %% [markdown]
# -------------------------------------------
# # Probabilidad y Estadística
# ## Facilitador: José Gabriel Rodríguez Rivas
# ## Alumna: Lluvia A. Saenz S.
# ------------------------------------------------------------------------------

# %% [markdown]
# ## FABRICAS DE 100 TELARES
# ### MEDIA,MODA,MEDIANA, HISTOGRAMAS
# ▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬

# %%
import matplotlib.pyplot as plt
from statistics import *
import random
import pandas as pd
import math

# %%
fabrica1 = []
for i in range(100):
  num_aleatorio = round(random.uniform(50,100),2)
  fabrica1.append(num_aleatorio)
print(fabrica1)
# Out:
# [57.39, 64.5, 91.35, 59.5, 76.38, 96.78, 75.32, 72.21, 97.48, 91.54, 54.97, 50.42, 52.47, 70.71, 81.3, 84.61, 86.16, 51.92, 55.24, 85.0, 97.37, 87.11, 90.04, 54.58, 86.65, 65.12, 88.53, 82.69, 56.33, 79.07, 59.02, 85.07, 90.25, 64.17, 78.7, 54.08, 74.45, 67.33, 52.38, 51.99, 50.85, 79.05, 52.04, 61.52, 66.39, 62.95, 63.26, 68.56, 69.61, 69.97, 84.31, 79.38, 54.04, 53.49, 62.38, 97.55, 86.85, 86.72, 67.4, 87.36, 67.21, 98.22, 65.79, 75.61, 71.55, 87.12, 96.09, 88.55, 79.25, 86.14, 66.32, 55.97, 73.48, 62.02, 65.03, 62.42, 56.22, 93.66, 57.62, 94.89, 62.04, 80.14, 68.73, 94.49, 61.64, 54.71, 63.88, 50.95, 94.6, 57.49, 87.96, 74.63, 67.46, 84.08, 96.39, 63.16, 57.76, 70.16, 99.5, 68.33]

# %%
fabrica2 = []
for i in range(100):
  num_aleatorio = round(random.uniform(50,100),2)
  fabrica2.append(num_aleatorio)
print(fabrica2)
# Out:
# [54.75, 79.18, 93.81, 70.05, 70.63, 55.38, 62.66, 72.5, 52.38, 77.51, 71.18, 81.81, 61.95, 81.13, 79.3, 93.66, 64.57, 52.24, 98.55, 60.88, 90.15, 51.92, 67.21, 87.05, 55.68, 90.39, 85.53, 80.24, 61.14, 79.74, 53.21, 96.64, 97.9, 98.64, 51.04, 85.02, 85.35, 62.54, 83.56, 94.18, 79.55, 80.3, 65.93, 71.36, 61.27, 69.23, 50.09, 55.98, 57.85, 89.22, 57.2, 87.24, 95.92, 54.73, 60.02, 50.06, 62.74, 68.38, 66.55, 70.79, 50.16, 61.24, 78.5, 80.4, 87.1, 73.14, 95.25, 92.68, 65.1, 81.05, 59.08, 88.33, 92.42, 94.6, 80.89, 59.19, 69.78, 78.16, 63.64, 80.98, 71.1, 69.91, 98.76, 80.81, 86.54, 81.03, 91.08, 88.98, 96.64, 96.66, 62.71, 84.44, 83.34, 82.57, 98.18, 65.85, 77.66, 75.8, 67.94, 74.67]

# %%
media = mean(fabrica1)
mediana = median(fabrica1)
moda = mode(fabrica1)
print("valores de la FABRICA 1")
print("la media es: ", media)
print("la mediana es: ",mediana)
print("la moda es: ",moda)
# Out:
# valores de la FABRICA 1
# la media es:  72.8512
# la mediana es:  70.065
# la moda es:  57.39

# %%
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)
print("valores de la FABRICA 2")
print("la media es: ", media)
print("la mediana es: ",mediana)
print("la moda es: ",moda)
# Out:
# valores de la FABRICA 2
# la media es:  72.8512
# la mediana es:  70.065
# la moda es:  57.39

# %%
plt.hist(fabrica1, bins=10, alpha=0.4, color='g', edgecolor= "black")
plt.axvline(media, color='b', linestyle='dashed', linewidth=2, label='media')
plt.axvline(moda, color='r', linestyle='dashed', linewidth=2, label='moda')
plt.axvline(mediana, color='magenta', linestyle='dashed', linewidth=2, label='mediana')
plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title("Produccion FABRICA1")
plt.legend()
plt.show()

# %%
plt.hist(fabrica2, bins=10, alpha=0.4, color='g', edgecolor= "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label='media')
plt.axvline(moda2, color='r', linestyle='dashed', linewidth=2, label='moda')
plt.axvline(mediana2, color='magenta', linestyle='dashed', linewidth=2, label='mediana')
plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title("Produccion FABRICA2")
plt.legend()
plt.show()

# %% [markdown]
# ## MAXIMO, MINIMO, RANGO
# ▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬

# %%
maximo = max(fabrica1)
minimo = min(fabrica1)
rango = maximo-minimo
print ("Estadistica descriptiva de la FABRICA1",
       "\n MEDIA =",media, "\n MEDIANA =", mediana, "\n MODA =", moda,
       "\n","\n MAXIMO =",maximo, "\n MINIMO =",minimo, "\n RANGO =",rango)
# Out:
# Estadistica descriptiva de la FABRICA1
#  MEDIA = 72.8512
#  MEDIANA = 70.065
#  MODA = 57.39
#
#  MAXIMO = 99.5
#  MINIMO = 50.42
#  RANGO = 49.08

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo-minimo
print ("Estadistica descriptiva de la FABRICA2",
       "\n MEDIA =",media2, "\n MEDIANA =", mediana2, "\n MODA =", moda2,
       "\n","\n MAXIMO =",maximo2, "\n MINIMO =",minimo2, "\n RANGO =",rango2)
# Out:
# Estadistica descriptiva de la FABRICA2
#  MEDIA = 75.1202
#  MEDIANA = 77.58500000000001
#  MODA = 96.64
#
#  MAXIMO = 98.76
#  MINIMO = 50.06
#  RANGO = 49.08

# %% [markdown]
# ## DISPERSION DE DATOS
# ▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬

# %%
desv_stand_fabrica1 = stdev(fabrica1)
print("la desviacion estandar de la FABRICA1 es ", desv_stand_fabrica1)
# Out:
# la desviacion estandar de la FABRICA1 es  14.633873896276446

# %%
desv_stand_fabrica2 = stdev(fabrica2)
print("la desviacion estandar de la FABRICA1 es ", desv_stand_fabrica2)
# Out:
# la desviacion estandar de la FABRICA1 es  14.295841521508303

# %%
plt.figure(figsize = (10,8))
plt.hist(fabrica1, bins=10, alpha=0.4, color='g', edgecolor= "black")
plt.axvline(media, color='b', linestyle='dashed', linewidth=2, label=f'media={media:.2f}')
plt.axvline(moda, color='r', linestyle='dashed', linewidth=2, label=f'moda ={moda:.2f}')
plt.axvline(mediana, color='magenta', linestyle='dashed', linewidth=2, label=f'mediana ={mediana:.2f}')

plt.axvline(media - desv_stand_fabrica1 , color='black', linestyle='dashed', linewidth=2, label=f'Desv. Estandar={desv_stand_fabrica1:.2f}')
plt.axvline(media + desv_stand_fabrica1 , color='black', linestyle='dashed', linewidth=2)

plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title("Produccion FABRICA1")
plt.legend()
plt.show()

# %%
plt.figure(figsize = (10,8))
plt.hist(fabrica2, bins=10, alpha=0.4, color='g', edgecolor= "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'media={media2:.2f}')
plt.axvline(moda2, color='r', linestyle='dashed', linewidth=2, label=f'moda ={moda2:.2f}')
plt.axvline(mediana2, color='magenta', linestyle='dashed', linewidth=2, label=f'mediana ={mediana2:.2f}')

plt.axvline(media2 - desv_stand_fabrica2 , color='black', linestyle='dashed', linewidth=2, label=f'Desv. Estandar={desv_stand_fabrica2:.2f}')
plt.axvline(media2 + desv_stand_fabrica2 , color='black', linestyle='dashed', linewidth=2)

plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title("Produccion FABRICA2")
plt.legend()
plt.show()

# %% [markdown]
# ## TABLA DE FRECUENCIAS
# ▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬

# %%
edades =[]
for i in range (100):
  num_aleatorio = random.randint(18,70)
  edades.append(num_aleatorio)
print(edades)
# Out:
# [40, 39, 70, 67, 19, 60, 61, 67, 34, 52, 51, 40, 70, 47, 19, 50, 21, 61, 27, 49, 66, 63, 59, 56, 69, 58, 35, 59, 70, 50, 58, 56, 42, 36, 50, 39, 52, 24, 23, 47, 54, 27, 66, 65, 65, 30, 28, 45, 23, 66, 42, 70, 47, 50, 43, 42, 34, 58, 37, 30, 26, 35, 39, 55, 49, 53, 65, 24, 33, 22, 37, 53, 49, 70, 26, 64, 23, 47, 66, 64, 36, 19, 52, 53, 45, 31, 40, 18, 28, 21, 42, 58, 41, 56, 58, 20, 58, 27, 40, 37]

# %%
df_edades = pd.DataFrame(edades, columns=["EDAD"])
df_edades
# Out:
#     EDAD
# 0     40
# 1     39
# 2     70
# 3     67
# 4     19
# ..   ...
# 95    20
# 96    58
# 97    27
# 98    40
# 99    37
#
# [100 rows x 1 columns]

# %%
tabla_frec = df_edades["EDAD"].value_counts().reset_index()
tabla_frec.columns = ["EDAD","FRECUENCIA"]
tabla_frec = tabla_frec.sort_values(by = "EDAD")
tabla_frec
# Out:
#     EDAD  FRECUENCIA
# 40    18           1
# 12    19           3
# 42    20           1
# 25    21           2
# 37    22           1
# 9     23           3
# 19    24           2
# 22    26           2
# 14    27           3
# 17    28           2
# 18    30           2
# 39    31           1
# 36    33           1
# 27    34           2
# 23    35           2
# 24    36           2
# 7     37           3
# 8     39           3
# 2     40           4
# 41    41           1
# 6     42           4
# 32    43           1
# 20    45           2
# 3     47           4
# 13    49           3
# 5     50           4
# 31    51           1
# 16    52           3
# 15    53           3
# 38    54           1
# 34    55           1
# 10    56           3
# 0     58           6
# 29    59           2
# 35    60           1
# 28    61           2
# 30    63           1
# 21    64           2
# 11    65           3
# 4     66           4
# 26    67           2
# 33    69           1
# ...

# %%
tabla_frec["Frec.RELATIVA"] = tabla_frec["FRECUENCIA"]/100
tabla_frec
# Out:
#     EDAD  FRECUENCIA  Frec.RELATIVA
# 40    18           1           0.01
# 12    19           3           0.03
# 42    20           1           0.01
# 25    21           2           0.02
# 37    22           1           0.01
# 9     23           3           0.03
# 19    24           2           0.02
# 22    26           2           0.02
# 14    27           3           0.03
# 17    28           2           0.02
# 18    30           2           0.02
# 39    31           1           0.01
# 36    33           1           0.01
# 27    34           2           0.02
# 23    35           2           0.02
# 24    36           2           0.02
# 7     37           3           0.03
# 8     39           3           0.03
# 2     40           4           0.04
# 41    41           1           0.01
# 6     42           4           0.04
# 32    43           1           0.01
# 20    45           2           0.02
# 3     47           4           0.04
# 13    49           3           0.03
# ...

# %%
tabla_frec["frec. PORCENTUAL"] = tabla_frec["FRECUENCIA"]/100*100
tabla_frec
# Out:
#     EDAD  FRECUENCIA  Frec.RELATIVA  frec. PORCENTUAL
# 40    18           1           0.01               1.0
# 12    19           3           0.03               3.0
# 42    20           1           0.01               1.0
# 25    21           2           0.02               2.0
# 37    22           1           0.01               1.0
# 9     23           3           0.03               3.0
# 19    24           2           0.02               2.0
# 22    26           2           0.02               2.0
# 14    27           3           0.03               3.0
# 17    28           2           0.02               2.0
# 18    30           2           0.02               2.0
# 39    31           1           0.01               1.0
# 36    33           1           0.01               1.0
# 27    34           2           0.02               2.0
# 23    35           2           0.02               2.0
# 24    36           2           0.02               2.0
# ...

# %%
tabla_frec["frec. ACUMULADA"] = tabla_frec["FRECUENCIA"].cumsum()
tabla_frec
# Out:
#     EDAD  FRECUENCIA  Frec.RELATIVA  frec. PORCENTUAL  frec. ACUMULADA
# 40    18           1           0.01               1.0                1
# 12    19           3           0.03               3.0                4
# 42    20           1           0.01               1.0                5
# 25    21           2           0.02               2.0                7
# 37    22           1           0.01               1.0                8
# 9     23           3           0.03               3.0               11
# 19    24           2           0.02               2.0               13
# 22    26           2           0.02               2.0               15
# 14    27           3           0.03               3.0               18
# 17    28           2           0.02               2.0               20
# 18    30           2           0.02               2.0               22
# 39    31           1           0.01               1.0               23
# ...

# %% [markdown]
# ## Regla De Sturgles
# ▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬
# 1. Calcula numero de clases o intervalos idoneo, en los que se debe de dividir un conjunto de datos
#
# $
# 𝑐=1+𝑙𝑜𝑔2(𝑁)
# $

# %%
df_edades_sturg = pd.DataFrame({ "EDADES":edades})
df_edades_sturg
# Out:
#     EDADES
# 0       40
# 1       39
# 2       70
# 3       67
# 4       19
# ..     ...
# 95      20
# 96      58
# 97      27
# 98      40
# 99      37
#
# [100 rows x 1 columns]

# %%
n = len(edades)
k = int(1+ math.log2(n))
print("N vale= ",n,"\nK vale= ",k)
# Out:
# N vale=  100
# K vale=  7

# %%
tabla_frec_sturges = pd.cut(df_edades_sturg["EDADES"],bins=k).value_counts().reset_index()
tabla_frec_sturges
# Out:
#              EDADES  count
# 0    (62.571, 70.0]     18
# 1  (32.857, 40.286]     17
# 2  (47.714, 55.143]     16
# 3  (55.143, 62.571]     14
# 4  (17.948, 25.429]     13
# 5  (40.286, 47.714]     12
# 6  (25.429, 32.857]     10

# %%
tabla_frec_sturges.columns = ["CLASE","FRECUENCIA"]
tabla_frec_sturges
# Out:
#               CLASE  FRECUENCIA
# 0    (62.571, 70.0]          18
# 1  (32.857, 40.286]          17
# 2  (47.714, 55.143]          16
# 3  (55.143, 62.571]          14
# 4  (17.948, 25.429]          13
# 5  (40.286, 47.714]          12
# 6  (25.429, 32.857]          10

# %%
tabla_frec_sturges = tabla_frec_sturges.sort_values(by = "CLASE")
tabla_frec_sturges
# Out:
#               CLASE  FRECUENCIA
# 4  (17.948, 25.429]          13
# 6  (25.429, 32.857]          10
# 1  (32.857, 40.286]          17
# 5  (40.286, 47.714]          12
# 2  (47.714, 55.143]          16
# 3  (55.143, 62.571]          14
# 0    (62.571, 70.0]          18

# %%
tabla_frec_sturges["frec. RELATIVA"] = tabla_frec_sturges["FRECUENCIA"] /n
tabla_frec_sturges["frec. PORCENTUAL"] = tabla_frec_sturges["FRECUENCIA"] /n*100
tabla_frec_sturges["frec. ACUMULADA"] = tabla_frec_sturges["FRECUENCIA"].cumsum()
tabla_frec_sturges
# Out:
#               CLASE  FRECUENCIA  frec. RELATIVA  frec. PORCENTUAL  \
# 4  (17.948, 25.429]          13            0.13              13.0
# 6  (25.429, 32.857]          10            0.10              10.0
# 1  (32.857, 40.286]          17            0.17              17.0
# 5  (40.286, 47.714]          12            0.12              12.0
# 2  (47.714, 55.143]          16            0.16              16.0
# 3  (55.143, 62.571]          14            0.14              14.0
# 0    (62.571, 70.0]          18            0.18              18.0
#
#    frec. ACUMULADA
# 4               13
# 6               23
# 1               40
# 5               52
# 2               68
# 3               82
# 0              100

# %%
plt.hist(df_edades_sturg["EDADES"],bins=k, alpha=0.5, rwidth=0.85)
plt.title("histograma edades REGLA STURGLES")
plt.ylabel("FRECUENCIA")
plt.xlabel("EDADES")
# Out:
# Text(0.5, 0, 'EDADES')

# %%
plt.hist(edades,alpha=0.5,rwidth= 0.85)
plt.title("EDADES valores estandar matplotlib")
plt.ylabel("FRECUENCIA")
plt.xlabel("EDADES")
# Out:
# Text(0.5, 0, 'EDADES')

# %% [markdown]
# ## Comparacion de produccion de las fabricas con DIAGRAMA DE CAJAS y BIGOTES
# ▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬▬

# %%
plt.boxplot(fabrica1)
plt.title("produccion de la fabrica1")
plt.ylabel("Produccion en Mts.")
plt.show()

# %%
plt.boxplot(fabrica2)
plt.title("produccion de la fabrica2")
plt.ylabel("Produccion en Mts.")
plt.show()

# %%
fig,(ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9,5))
ax1.boxplot( fabrica1, vert = True, patch_artist=True)
ax1.set_title("Produccion de la fabrica1")
ax2.boxplot( fabrica2, vert = True, patch_artist=True)
ax2.set_title("Produccion de la fabrica2")
plt.show()
